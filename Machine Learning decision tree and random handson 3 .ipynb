# %% [markdown]
# # Import Packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %% [markdown]
# # Load in Data

# %%
Titanic = sns.load_dataset('titanic')

# %%
Titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %% [markdown]
# # Data Wrangling

# %% [markdown]
# ### Drop any variables that are redundant and will add to multicollinearity.

# %%
Titanic1= Titanic.drop('fare', axis= 1)

# %%
Titanic1
# Out:
#      survived  pclass     sex   age  sibsp  parch embarked   class    who  \
# 0           0       3    male  22.0      1      0        S   Third    man
# 1           1       1  female  38.0      1      0        C   First  woman
# 2           1       3  female  26.0      0      0        S   Third  woman
# 3           1       1  female  35.0      1      0        S   First  woman
# 4           0       3    male  35.0      0      0        S   Third    man
# ..        ...     ...     ...   ...    ...    ...      ...     ...    ...
# 886         0       2    male  27.0      0      0        S  Second    man
# 887         1       1  female  19.0      0      0        S   First  woman
# 888         0       3  female   NaN      1      2        S   Third  woman
# 889         1       1    male  26.0      0      0        C   First    man
# 890         0       3    male  32.0      0      0        Q   Third    man
#
#      adult_male deck  embark_town alive  alone
# 0          True  NaN  Southampton    no  False
# 1         False    C    Cherbourg   yes  False
# 2         False  NaN  Southampton   yes   True
# 3         False    C  Southampton   yes  False
# 4          True  NaN  Southampton    no   True
# ..          ...  ...          ...   ...    ...
# 886        True  NaN  Southampton    no   True
# 887       False    B  Southampton   yes   True
# 888       False  NaN  Southampton    no  False
# 889        True    C    Cherbourg   yes   True
# 890        True  NaN   Queenstown    no   True
#
# [891 rows x 14 columns]

# %%
Titanic2= Titanic1.drop('adult_male', axis= 1)

# %%
Titanic2
# Out:
#      survived  pclass     sex   age  sibsp  parch embarked   class    who  \
# 0           0       3    male  22.0      1      0        S   Third    man
# 1           1       1  female  38.0      1      0        C   First  woman
# 2           1       3  female  26.0      0      0        S   Third  woman
# 3           1       1  female  35.0      1      0        S   First  woman
# 4           0       3    male  35.0      0      0        S   Third    man
# ..        ...     ...     ...   ...    ...    ...      ...     ...    ...
# 886         0       2    male  27.0      0      0        S  Second    man
# 887         1       1  female  19.0      0      0        S   First  woman
# 888         0       3  female   NaN      1      2        S   Third  woman
# 889         1       1    male  26.0      0      0        C   First    man
# 890         0       3    male  32.0      0      0        Q   Third    man
#
#     deck  embark_town alive  alone
# 0    NaN  Southampton    no  False
# 1      C    Cherbourg   yes  False
# 2    NaN  Southampton   yes   True
# 3      C  Southampton   yes  False
# 4    NaN  Southampton    no   True
# ..   ...          ...   ...    ...
# 886  NaN  Southampton    no   True
# 887    B  Southampton   yes   True
# 888  NaN  Southampton    no  False
# 889    C    Cherbourg   yes   True
# 890  NaN   Queenstown    no   True
#
# [891 rows x 13 columns]

# %%
Titanic3= Titanic2.drop('alone', axis= 1)

# %%
Titanic3
# Out:
#      survived  pclass     sex   age  sibsp  parch embarked   class    who  \
# 0           0       3    male  22.0      1      0        S   Third    man
# 1           1       1  female  38.0      1      0        C   First  woman
# 2           1       3  female  26.0      0      0        S   Third  woman
# 3           1       1  female  35.0      1      0        S   First  woman
# 4           0       3    male  35.0      0      0        S   Third    man
# ..        ...     ...     ...   ...    ...    ...      ...     ...    ...
# 886         0       2    male  27.0      0      0        S  Second    man
# 887         1       1  female  19.0      0      0        S   First  woman
# 888         0       3  female   NaN      1      2        S   Third  woman
# 889         1       1    male  26.0      0      0        C   First    man
# 890         0       3    male  32.0      0      0        Q   Third    man
#
#     deck  embark_town alive
# 0    NaN  Southampton    no
# 1      C    Cherbourg   yes
# 2    NaN  Southampton   yes
# 3      C  Southampton   yes
# 4    NaN  Southampton    no
# ..   ...          ...   ...
# 886  NaN  Southampton    no
# 887    B  Southampton   yes
# 888  NaN  Southampton    no
# 889    C    Cherbourg   yes
# 890  NaN   Queenstown    no
#
# [891 rows x 12 columns]

# %%
Titanic.pclass.value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: pclass, dtype: int64

# %%
Titanic.embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: embarked, dtype: int64

# %%
Titanic.embark_town.value_counts()
# Out:
# Southampton    644
# Cherbourg      168
# Queenstown      77
# Name: embark_town, dtype: int64

# %% [markdown]
# #Embark_town and embarked are the basically the same thing will drop embarked

# %%
Titanic4= Titanic3.drop('embarked', axis= 1)

# %%
Titanic4
# Out:
#      survived  pclass     sex   age  sibsp  parch   class    who deck  \
# 0           0       3    male  22.0      1      0   Third    man  NaN
# 1           1       1  female  38.0      1      0   First  woman    C
# 2           1       3  female  26.0      0      0   Third  woman  NaN
# 3           1       1  female  35.0      1      0   First  woman    C
# 4           0       3    male  35.0      0      0   Third    man  NaN
# ..        ...     ...     ...   ...    ...    ...     ...    ...  ...
# 886         0       2    male  27.0      0      0  Second    man  NaN
# 887         1       1  female  19.0      0      0   First  woman    B
# 888         0       3  female   NaN      1      2   Third  woman  NaN
# 889         1       1    male  26.0      0      0   First    man    C
# 890         0       3    male  32.0      0      0   Third    man  NaN
#
#      embark_town alive
# 0    Southampton    no
# 1      Cherbourg   yes
# 2    Southampton   yes
# 3    Southampton   yes
# 4    Southampton    no
# ..           ...   ...
# 886  Southampton    no
# 887  Southampton   yes
# 888  Southampton    no
# 889    Cherbourg   yes
# 890   Queenstown    no
#
# [891 rows x 11 columns]

# %%
Titanic["class"].value_counts()
# Out:
# Third     491
# First     216
# Second    184
# Name: class, dtype: int64

# %% [markdown]
# #Pclass and class are basically the same things will drop pclass

# %%
Titanic5= Titanic4.drop('pclass', axis= 1)

# %%
Titanic5
# Out:
#      survived     sex   age  sibsp  parch   class    who deck  embark_town  \
# 0           0    male  22.0      1      0   Third    man  NaN  Southampton
# 1           1  female  38.0      1      0   First  woman    C    Cherbourg
# 2           1  female  26.0      0      0   Third  woman  NaN  Southampton
# 3           1  female  35.0      1      0   First  woman    C  Southampton
# 4           0    male  35.0      0      0   Third    man  NaN  Southampton
# ..        ...     ...   ...    ...    ...     ...    ...  ...          ...
# 886         0    male  27.0      0      0  Second    man  NaN  Southampton
# 887         1  female  19.0      0      0   First  woman    B  Southampton
# 888         0  female   NaN      1      2   Third  woman  NaN  Southampton
# 889         1    male  26.0      0      0   First    man    C    Cherbourg
# 890         0    male  32.0      0      0   Third    man  NaN   Queenstown
#
#     alive
# 0      no
# 1     yes
# 2     yes
# 3     yes
# 4      no
# ..    ...
# 886    no
# 887   yes
# 888    no
# 889   yes
# 890    no
#
# [891 rows x 10 columns]

# %% [markdown]
# ### Recode string data

# %%
Titanic5.sex.value_counts()
# Out:
# male      577
# female    314
# Name: sex, dtype: int64

# %%
def sex(series):
    if series == "male":
        return "0"
    if series == "female":
        return "1"
Titanic5["sexR"]= Titanic5["sex"].apply(sex)

# %%
Titanic5["class"].value_counts()
# Out:
# Third     491
# First     216
# Second    184
# Name: class, dtype: int64

# %%
def class1(series):
    if series == "First":
        return "0"
    if series == "Second":
        return "1"
    if series == "Third":
        return "2"
Titanic5["classR"]= Titanic5["class"].apply(class1)

# %%
Titanic5.who.value_counts()
# Out:
# man      537
# woman    271
# child     83
# Name: who, dtype: int64

# %%
def who(series):
    if series == "man":
        return "0"
    if series == "woman":
        return "1"
    if series == "child":
        return "2"
Titanic5["whoR"]=Titanic5["who"].apply(who)

# %%
Titanic5
# Out:
#      survived     sex   age  sibsp  parch   class    who deck  embark_town  \
# 0           0    male  22.0      1      0   Third    man  NaN  Southampton
# 1           1  female  38.0      1      0   First  woman    C    Cherbourg
# 2           1  female  26.0      0      0   Third  woman  NaN  Southampton
# 3           1  female  35.0      1      0   First  woman    C  Southampton
# 4           0    male  35.0      0      0   Third    man  NaN  Southampton
# ..        ...     ...   ...    ...    ...     ...    ...  ...          ...
# 886         0    male  27.0      0      0  Second    man  NaN  Southampton
# 887         1  female  19.0      0      0   First  woman    B  Southampton
# 888         0  female   NaN      1      2   Third  woman  NaN  Southampton
# 889         1    male  26.0      0      0   First    man    C    Cherbourg
# 890         0    male  32.0      0      0   Third    man  NaN   Queenstown
#
#     alive sexR classR whoR
# 0      no    0      2    0
# 1     yes    1      0    1
# 2     yes    1      2    1
# 3     yes    1      0    1
# 4      no    0      2    0
# ..    ...  ...    ...  ...
# 886    no    0      1    0
# 887   yes    1      0    1
# 888    no    1      2    1
# 889   yes    0      0    0
# 890    no    0      2    0
#
# [891 rows x 13 columns]

# %%
Titanic5.survived.value_counts()
# Out:
# 0    549
# 1    342
# Name: survived, dtype: int64

# %%
Titanic5.alive.value_counts()
# Out:
# no     549
# yes    342
# Name: alive, dtype: int64

# %%
Titanic5
# Out:
#      survived     sex   age  sibsp  parch   class    who deck  embark_town  \
# 0           0    male  22.0      1      0   Third    man  NaN  Southampton
# 1           1  female  38.0      1      0   First  woman    C    Cherbourg
# 2           1  female  26.0      0      0   Third  woman  NaN  Southampton
# 3           1  female  35.0      1      0   First  woman    C  Southampton
# 4           0    male  35.0      0      0   Third    man  NaN  Southampton
# ..        ...     ...   ...    ...    ...     ...    ...  ...          ...
# 886         0    male  27.0      0      0  Second    man  NaN  Southampton
# 887         1  female  19.0      0      0   First  woman    B  Southampton
# 888         0  female   NaN      1      2   Third  woman  NaN  Southampton
# 889         1    male  26.0      0      0   First    man    C    Cherbourg
# 890         0    male  32.0      0      0   Third    man  NaN   Queenstown
#
#     alive sexR classR whoR
# 0      no    0      2    0
# 1     yes    1      0    1
# 2     yes    1      2    1
# 3     yes    1      0    1
# 4      no    0      2    0
# ..    ...  ...    ...  ...
# 886    no    0      1    0
# 887   yes    1      0    1
# 888    no    1      2    1
# 889   yes    0      0    0
# 890    no    0      2    0
#
# [891 rows x 13 columns]

# %%
Titanic5= Titanic5.drop('alive', axis= 1)

# %%
Titanic5
# Out:
#      survived     sex   age  sibsp  parch   class    who deck  embark_town  \
# 0           0    male  22.0      1      0   Third    man  NaN  Southampton
# 1           1  female  38.0      1      0   First  woman    C    Cherbourg
# 2           1  female  26.0      0      0   Third  woman  NaN  Southampton
# 3           1  female  35.0      1      0   First  woman    C  Southampton
# 4           0    male  35.0      0      0   Third    man  NaN  Southampton
# ..        ...     ...   ...    ...    ...     ...    ...  ...          ...
# 886         0    male  27.0      0      0  Second    man  NaN  Southampton
# 887         1  female  19.0      0      0   First  woman    B  Southampton
# 888         0  female   NaN      1      2   Third  woman  NaN  Southampton
# 889         1    male  26.0      0      0   First    man    C    Cherbourg
# 890         0    male  32.0      0      0   Third    man  NaN   Queenstown
#
#     sexR classR whoR
# 0      0      2    0
# 1      1      0    1
# 2      1      2    1
# 3      1      0    1
# 4      0      2    0
# ..   ...    ...  ...
# 886    0      1    0
# 887    1      0    1
# 888    1      2    1
# 889    0      0    0
# 890    0      2    0
#
# [891 rows x 12 columns]

# %%
Titanic5.deck.value_counts()
# Out:
# C    59
# B    47
# D    33
# E    32
# A    15
# F    13
# G     4
# Name: deck, dtype: int64

# %%
def deck(series):
    if series == "C":
        return "0"
    if series == "B":
        return "1"
    if series == "D":
        return "2"
    if series == "E":
        return "3"
    if series == "A":
        return "4"
    if series == "F":
        return "5"
    if series == "G":
        return "6"
Titanic5["deckR"]= Titanic5["deck"].apply(deck)

# %%
Titanic5
# Out:
#      survived     sex   age  sibsp  parch   class    who deck  embark_town  \
# 0           0    male  22.0      1      0   Third    man  NaN  Southampton
# 1           1  female  38.0      1      0   First  woman    C    Cherbourg
# 2           1  female  26.0      0      0   Third  woman  NaN  Southampton
# 3           1  female  35.0      1      0   First  woman    C  Southampton
# 4           0    male  35.0      0      0   Third    man  NaN  Southampton
# ..        ...     ...   ...    ...    ...     ...    ...  ...          ...
# 886         0    male  27.0      0      0  Second    man  NaN  Southampton
# 887         1  female  19.0      0      0   First  woman    B  Southampton
# 888         0  female   NaN      1      2   Third  woman  NaN  Southampton
# 889         1    male  26.0      0      0   First    man    C    Cherbourg
# 890         0    male  32.0      0      0   Third    man  NaN   Queenstown
#
#     sexR classR whoR deckR
# 0      0      2    0   NaN
# 1      1      0    1     0
# 2      1      2    1   NaN
# 3      1      0    1     0
# 4      0      2    0   NaN
# ..   ...    ...  ...   ...
# 886    0      1    0   NaN
# 887    1      0    1     1
# 888    1      2    1   NaN
# 889    0      0    0     0
# 890    0      2    0   NaN
#
# [891 rows x 13 columns]

# %%
Titanic5.embark_town.value_counts()
# Out:
# Southampton    644
# Cherbourg      168
# Queenstown      77
# Name: embark_town, dtype: int64

# %%
def town(series):
    if series == "Southampton":
        return "0"
    if series == "Cherbourg":
        return "1"
    if series == "Queenstown":
        return "2"
Titanic5["embark_townR"]= Titanic5["embark_town"].apply(town)

# %%
Titanic5
# Out:
#      survived     sex   age  sibsp  parch   class    who deck  embark_town  \
# 0           0    male  22.0      1      0   Third    man  NaN  Southampton
# 1           1  female  38.0      1      0   First  woman    C    Cherbourg
# 2           1  female  26.0      0      0   Third  woman  NaN  Southampton
# 3           1  female  35.0      1      0   First  woman    C  Southampton
# 4           0    male  35.0      0      0   Third    man  NaN  Southampton
# ..        ...     ...   ...    ...    ...     ...    ...  ...          ...
# 886         0    male  27.0      0      0  Second    man  NaN  Southampton
# 887         1  female  19.0      0      0   First  woman    B  Southampton
# 888         0  female   NaN      1      2   Third  woman  NaN  Southampton
# 889         1    male  26.0      0      0   First    man    C    Cherbourg
# 890         0    male  32.0      0      0   Third    man  NaN   Queenstown
#
#     sexR classR whoR deckR embark_townR
# 0      0      2    0   NaN            0
# 1      1      0    1     0            1
# 2      1      2    1   NaN            0
# 3      1      0    1     0            0
# 4      0      2    0   NaN            0
# ..   ...    ...  ...   ...          ...
# 886    0      1    0   NaN            0
# 887    1      0    1     1            0
# 888    1      2    1   NaN            0
# 889    0      0    0     0            1
# 890    0      2    0   NaN            2
#
# [891 rows x 14 columns]

# %% [markdown]
# ### Making sure the data is in the right format

# %%
Titanic5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   survived      891 non-null    int64
#  1   sex           891 non-null    object
#  2   age           714 non-null    float64
#  3   sibsp         891 non-null    int64
#  4   parch         891 non-null    int64
#  5   class         891 non-null    category
#  6   who           891 non-null    object
#  7   deck          203 non-null    category
#  8   embark_town   889 non-null    object
#  9   sexR          891 non-null    object
#  10  classR        891 non-null    category
#  11  whoR          891 non-null    object
#  12  deckR         203 non-null    category
#  13  embark_townR  889 non-null    object
# dtypes: category(4), float64(1), int64(3), object(6)
# memory usage: 74.2+ KB

# %%
Titanic5['deckR']= pd.to_numeric(Titanic5['deckR'], errors='coerce')

# %%
Titanic5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   survived      891 non-null    int64
#  1   sex           891 non-null    object
#  2   age           714 non-null    float64
#  3   sibsp         891 non-null    int64
#  4   parch         891 non-null    int64
#  5   class         891 non-null    category
#  6   who           891 non-null    object
#  7   deck          203 non-null    category
#  8   embark_town   889 non-null    object
#  9   sexR          891 non-null    object
#  10  classR        891 non-null    category
#  11  whoR          891 non-null    object
#  12  deckR         203 non-null    float64
#  13  embark_townR  889 non-null    object
# dtypes: category(3), float64(2), int64(3), object(6)
# memory usage: 79.9+ KB

# %%
Titanic5
# Out:
#      survived     sex   age  sibsp  parch   class    who deck  embark_town  \
# 0           0    male  22.0      1      0   Third    man  NaN  Southampton
# 1           1  female  38.0      1      0   First  woman    C    Cherbourg
# 2           1  female  26.0      0      0   Third  woman  NaN  Southampton
# 3           1  female  35.0      1      0   First  woman    C  Southampton
# 4           0    male  35.0      0      0   Third    man  NaN  Southampton
# ..        ...     ...   ...    ...    ...     ...    ...  ...          ...
# 886         0    male  27.0      0      0  Second    man  NaN  Southampton
# 887         1  female  19.0      0      0   First  woman    B  Southampton
# 888         0  female   NaN      1      2   Third  woman  NaN  Southampton
# 889         1    male  26.0      0      0   First    man    C    Cherbourg
# 890         0    male  32.0      0      0   Third    man  NaN   Queenstown
#
#     sexR classR whoR  deckR embark_townR
# 0      0      2    0    NaN            0
# 1      1      0    1    0.0            1
# 2      1      2    1    NaN            0
# 3      1      0    1    0.0            0
# 4      0      2    0    NaN            0
# ..   ...    ...  ...    ...          ...
# 886    0      1    0    NaN            0
# 887    1      0    1    1.0            0
# 888    1      2    1    NaN            0
# 889    0      0    0    0.0            1
# 890    0      2    0    NaN            2
#
# [891 rows x 14 columns]

# %% [markdown]
# # will try dropping missing data

# %%
Titanic5.dropna(inplace=True)

# %%
Titanic5
# Out:
#      survived     sex   age  sibsp  parch  class    who deck  embark_town  \
# 1           1  female  38.0      1      0  First  woman    C    Cherbourg
# 3           1  female  35.0      1      0  First  woman    C  Southampton
# 6           0    male  54.0      0      0  First    man    E  Southampton
# 10          1  female   4.0      1      1  Third  child    G  Southampton
# 11          1  female  58.0      0      0  First  woman    C  Southampton
# ..        ...     ...   ...    ...    ...    ...    ...  ...          ...
# 871         1  female  47.0      1      1  First  woman    D  Southampton
# 872         0    male  33.0      0      0  First    man    B  Southampton
# 879         1  female  56.0      0      1  First  woman    C    Cherbourg
# 887         1  female  19.0      0      0  First  woman    B  Southampton
# 889         1    male  26.0      0      0  First    man    C    Cherbourg
#
#     sexR classR whoR  deckR embark_townR
# 1      1      0    1    0.0            1
# 3      1      0    1    0.0            0
# 6      0      0    0    3.0            0
# 10     1      2    2    6.0            0
# 11     1      0    1    0.0            0
# ..   ...    ...  ...    ...          ...
# 871    1      0    1    2.0            0
# 872    0      0    0    1.0            0
# 879    1      0    1    0.0            1
# 887    1      0    1    1.0            0
# 889    0      0    0    0.0            1
#
# [182 rows x 14 columns]

# %% [markdown]
# # Identitfy x and y

# %%
x = Titanic5[['sexR','age', 'sibsp', 'parch', 'classR','whoR','deckR','embark_townR']]
y = Titanic5['survived']

# %% [markdown]
# # Train Test Split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.3)

# %%
decisionTree = DecisionTreeClassifier()
decisionTree.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# # Assess the Model

# %%
treePredictions = decisionTree.predict(x_test)

# %% [markdown]
# # Reading the Confusion Matrix

# %%
print(confusion_matrix(y_test, treePredictions))
# Out:
# [[ 9  9]
#  [ 7 30]]

# %%
print(classification_report(y_test, treePredictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.56      0.50      0.53        18
#            1       0.77      0.81      0.79        37
#
#     accuracy                           0.71        55
#    macro avg       0.67      0.66      0.66        55
# weighted avg       0.70      0.71      0.70        55

# %% [markdown]
# The weighted average tells us that 70% of the time the predictions we make are accurate which is not too bad. We do very well in predicting who survived not the best in who did not.

# %% [markdown]
# # This was really hard on to the next :)

# %% [markdown]
# # PART 2 - Random Forest

# %% [markdown]
# # Initial Random Forest Model

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

# %%
forest = RandomForestClassifier()
forest.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
forestPredictions = forest.predict(x_test)
print(confusion_matrix(y_test, forestPredictions))
print(classification_report(y_test, forestPredictions))
# Out:
# [[ 8 10]
#  [ 8 29]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.44      0.47        18
#            1       0.74      0.78      0.76        37
#
#     accuracy                           0.67        55
#    macro avg       0.62      0.61      0.62        55
# weighted avg       0.66      0.67      0.67        55

# %% [markdown]
# Looking at this again we see that better predicition are made with those who survived then those who died and that is reflected with the precision, recall, and F1 score. The weighted average depects a decreased precentage from the decision tree model. Now, there is a 66% accuracy which is not that good.

# %% [markdown]
# # Finally completed!! :)
